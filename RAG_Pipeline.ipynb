# %%
import os
import sys
from getpass import getpass
import nest_asyncio

from dotenv import load_dotenv

nest_asyncio.apply()

load_dotenv()
# Out:
# True

# %%
import os
import json
from typing import Dict, List, Optional, Tuple
from notion_client import Client
import pandas as pd
from datetime import datetime

class NotionProcessor:
    def __init__(self, auth_token: str):
        """Initialize the Notion client with authentication token."""
        self.notion = Client(auth=auth_token)
    
    def get_database_pages(self, database_id: str, parent_properties: Dict = None) -> List[Dict]:
        """
        Retrieve all pages from a Notion database.
        If parent_properties provided, merge them with each page's properties.
        """
        pages = []
        cursor = None
        
        while True:
            response = self.notion.databases.query(
                database_id=database_id,
                start_cursor=cursor
            )
            
            # If parent properties exist, merge them with each page
            if parent_properties:
                for page in response['results']:
                    self._merge_parent_properties(page, parent_properties)
            
            pages.extend(response['results'])
            
            if not response.get('has_more'):
                break
                
            cursor = response['next_cursor']
            
        return pages
    
    def _merge_parent_properties(self, page: Dict, parent_properties: Dict):
        """Merge parent properties into page properties, avoiding duplicates."""
        for key, value in parent_properties.items():
            if key not in page['properties']:
                # Create a new property of type 'rich_text' to store inherited values
                page['properties'][f'parent_{key}'] = {
                    'type': 'rich_text',
                    'rich_text': [{
                        'type': 'text',
                        'text': {'content': str(value)},
                        'plain_text': str(value)
                    }]
                }
    
    def extract_properties(self, page: Dict) -> Dict:
        """Extract properties from a page."""
        properties = {}
        
        for prop_name, prop_data in page['properties'].items():
            prop_type = prop_data['type']
            
            if prop_type == 'title':
                properties[prop_name] = self._get_rich_text_content(prop_data['title'])
            elif prop_type == 'rich_text':
                properties[prop_name] = self._get_rich_text_content(prop_data['rich_text'])
            elif prop_type == 'select':
                if prop_data['select']:
                    properties[prop_name] = prop_data['select']['name']
            elif prop_type == 'multi_select':
                properties[prop_name] = [item['name'] for item in prop_data['multi_select']]
            elif prop_type == 'date':
                if prop_data['date']:
                    properties[prop_name] = prop_data['date']['start']
            elif prop_type in ['number', 'checkbox']:
                properties[prop_name] = prop_data[prop_type]
                
        return properties
    
    def _get_rich_text_content(self, rich_text: List) -> str:
        """Extract text content from rich text array."""
        return ' '.join([text['plain_text'] for text in rich_text if text.get('plain_text')])
    
    def get_block_children(self, block_id: str, level: int = 0) -> List[Tuple[Dict, int]]:
        """Retrieve all child blocks of a given block with their nesting level."""
        blocks = []
        cursor = None
        
        while True:
            response = self.notion.blocks.children.list(
                block_id=block_id,
                start_cursor=cursor
            )
            
            for block in response['results']:
                blocks.append((block, level))
                
                if block.get('has_children'):
                    # For child database blocks, don't process them here
                    if block['type'] != 'child_database':
                        child_blocks = self.get_block_children(block['id'], level + 1)
                        blocks.extend(child_blocks)
            
            if not response.get('has_more'):
                break
                
            cursor = response['next_cursor']
            
        return blocks
    
    def process_blocks(self, blocks: List[Tuple[Dict, int]]) -> Tuple[Dict, List[str]]:
        """
        Process blocks to extract headers (with sub-headers) and content.
        Returns tuple of (headers_dict, content_sections).
        """
        current_main_header = None
        current_sub_headers = []
        current_content = []
        headers = {}
        content_sections = []
        current_bullet_group = []
        
        def save_current_section():
            """Helper function to save current section's content."""
            nonlocal current_content, current_bullet_group, content_sections, current_main_header, current_sub_headers, headers
            
            # Save any remaining bullet group
            if current_bullet_group:
                current_content.append(self._merge_bullet_group(current_bullet_group))
                current_bullet_group = []
            
            # Save content if exists and we have a header
            if current_main_header is not None and current_content:
                content_sections.append('\n'.join(filter(None, current_content)))
                full_header = current_main_header
                if current_sub_headers:
                    full_header += ' - ' + ' - '.join(current_sub_headers)
                headers[full_header] = len(content_sections) - 1  # Point to the section we just added
        
        for block, level in blocks:
            block_type = block['type']
            
            # Handle headers
            if block_type.startswith('heading_'):
                # Save current section before starting new one
                save_current_section()
                
                # Reset content collection for new section
                current_content = []
                current_bullet_group = []
                
                # Process new header
                header_text = self._get_rich_text_content(block[block_type]['rich_text'])
                header_level = int(block_type[-1])
                
                if header_level == 1:
                    current_main_header = header_text
                    current_sub_headers = []
                else:
                    current_sub_headers.append(header_text)
            
            # Handle child database
            elif block_type == 'child_database':
                if current_bullet_group:
                    current_content.append(self._merge_bullet_group(current_bullet_group))
                    current_bullet_group = []
                current_content.append(f"[Database: {block['id']}]")
            
            # Handle bullet points and numbered lists
            elif block_type in ['bulleted_list_item', 'numbered_list_item']:
                text_content = self._get_rich_text_content(block[block_type]['rich_text'])
                
                if level == 0:
                    if current_bullet_group:
                        current_content.append(self._merge_bullet_group(current_bullet_group))
                        current_bullet_group = []
                    current_bullet_group = [(text_content, level)]
                else:
                    current_bullet_group.append((text_content, level))
            
            # Handle regular paragraphs
            elif block_type == 'paragraph':
                if current_bullet_group:
                    current_content.append(self._merge_bullet_group(current_bullet_group))
                    current_bullet_group = []
                
                text_content = self._get_rich_text_content(block[block_type]['rich_text'])
                if text_content:
                    current_content.append(text_content)
        
        # Save final section
        save_current_section()
        
        return headers, content_sections
    
    def _merge_bullet_group(self, bullet_group: List[Tuple[str, int]]) -> str:
        """Merge a group of bullets into a single line, with sub-bullets inline."""
        if not bullet_group:
            return ""
        
        result = []
        current_main_bullet = []
        
        for text, level in bullet_group:
            if level == 0:
                if current_main_bullet:
                    result.append(' '.join(current_main_bullet))
                current_main_bullet = [text]
            else:
                current_main_bullet.append(text)
        
        if current_main_bullet:
            result.append(' '.join(current_main_bullet))
        
        return '\n'.join(result)
    
    def process_page(self, page: Dict, parent_properties: Dict = None) -> List[Dict]:
        """Process a single page and its nested databases."""
        results = []
        properties = self.extract_properties(page)
        
        # Merge parent properties if they exist
        if parent_properties:
            properties.update({f'parent_{k}': v for k, v in parent_properties.items()})
        
        # Process page blocks
        blocks = self.get_block_children(page['id'])
        headers, content_sections = self.process_blocks(blocks)
        
        # Add headers to properties and create entries
        for header, section_index in headers.items():
            section_properties = properties.copy()
            section_properties['header'] = header
            
            # Create entry for this section
            if 0 <= section_index < len(content_sections):
                results.append({
                    'properties': section_properties,
                    'content': content_sections[section_index]
                })
        
        # Process any child databases found in the blocks
        for block, _ in blocks:
            if block['type'] == 'child_database':
                child_pages = self.get_database_pages(block['id'], properties)
                for child_page in child_pages:
                    results.extend(self.process_page(child_page, properties))
        
        return results
    
    def process_database(self, database_id: str) -> List[Dict]:
        """Process entire database and return structured data."""
        processed_data = []
        
        # Get all pages from the database
        pages = self.get_database_pages(database_id)
        
        # Process each page and its nested databases
        for page in pages:
            processed_data.extend(self.process_page(page))
            
        return processed_data

# Example usage in Jupyter notebook (separate cells):

# %%
# Example usage in Jupyter notebook (separate cells):

# Cell 1: Initialize processor
NOTION_TOKEN = os.getenv("NOTION_TOKEN")
DATABASE_ID = os.getenv("NOTION_DATABASE_ID")

processor = NotionProcessor(NOTION_TOKEN)
processed_data = processor.process_database(DATABASE_ID)
# Out:
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/ea8dc36afe024100a4cc64c52b1bc782/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/ea8dc36afe024100a4cc64c52b1bc782/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/ea8dc36afe024100a4cc64c52b1bc782/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-8034-bf81-ce94b2407e72/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-8034-bf81-ce94b2407e72/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-8034-bf81-ce94b2407e72/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-806f-8558-f25c6938f449/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-806f-8558-f25c6938f449/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-806f-8558-f25c6938f449/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80b7-8126-ed5c0cf06944/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80b7-8126-ed5c0cf06944/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80b7-8126-ed5c0cf06944/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-805c-a982-d7fbc36f39ac/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-805c-a982-d7fbc36f39ac/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-805c-a982-d7fbc36f39ac/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80b1-8618-fb20d860acef/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80b1-8618-fb20d860acef/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80b1-8618-fb20d860acef/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80e1-b77c-d52c34ec5ca6/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80e1-b77c-d52c34ec5ca6/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1191e09c-3048-80e1-b77c-d52c34ec5ca6/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/b7d5bd7c-f77c-446f-9eaf-8780b5f48e1c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b7d5bd7c-f77c-446f-9eaf-8780b5f48e1c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b7d5bd7c-f77c-446f-9eaf-8780b5f48e1c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/906e9719-ccb1-4ddd-b800-abda20f123bf/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/906e9719-ccb1-4ddd-b800-abda20f123bf/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/906e9719-ccb1-4ddd-b800-abda20f123bf/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/2917654b-7e05-44d0-a7da-90d6f2b8b072/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2917654b-7e05-44d0-a7da-90d6f2b8b072/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2917654b-7e05-44d0-a7da-90d6f2b8b072/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ec3070ff-4d07-4109-9cab-04f1fbe53fc7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ec3070ff-4d07-4109-9cab-04f1fbe53fc7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ec3070ff-4d07-4109-9cab-04f1fbe53fc7/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/a1135ea0-1a96-46a2-b984-567d0a8432d4/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a1135ea0-1a96-46a2-b984-567d0a8432d4/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a1135ea0-1a96-46a2-b984-567d0a8432d4/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/14b75365-665d-4bfe-8eee-a882d30b50f8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/14b75365-665d-4bfe-8eee-a882d30b50f8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/14b75365-665d-4bfe-8eee-a882d30b50f8/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/5875da5b-5fa7-4d56-b08d-23012e4eba32/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5875da5b-5fa7-4d56-b08d-23012e4eba32/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5875da5b-5fa7-4d56-b08d-23012e4eba32/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/5a253127-1782-4c0e-8357-bed73ff68c54/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5a253127-1782-4c0e-8357-bed73ff68c54/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5a253127-1782-4c0e-8357-bed73ff68c54/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e116fe93-4102-4512-ac7a-1d81a404b214/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e116fe93-4102-4512-ac7a-1d81a404b214/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e116fe93-4102-4512-ac7a-1d81a404b214/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/7a96da3d-55f6-4956-8dee-aa18ce98eb4c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7a96da3d-55f6-4956-8dee-aa18ce98eb4c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7a96da3d-55f6-4956-8dee-aa18ce98eb4c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ac533115-2dc2-4195-af35-552467553c63/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ac533115-2dc2-4195-af35-552467553c63/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ac533115-2dc2-4195-af35-552467553c63/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/29b7515a-40d9-4cec-a662-473ae0ae13f8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/29b7515a-40d9-4cec-a662-473ae0ae13f8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/29b7515a-40d9-4cec-a662-473ae0ae13f8/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d3f31a14-be6c-4130-9c23-7a30ea4b7d48/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d3f31a14-be6c-4130-9c23-7a30ea4b7d48/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d3f31a14-be6c-4130-9c23-7a30ea4b7d48/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/bb001aa4-bc80-47d4-8c87-1d95409f09e5/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/bb001aa4-bc80-47d4-8c87-1d95409f09e5/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/bb001aa4-bc80-47d4-8c87-1d95409f09e5/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e0076b18-f8c1-4af3-8ec9-c8790e728504/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e0076b18-f8c1-4af3-8ec9-c8790e728504/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e0076b18-f8c1-4af3-8ec9-c8790e728504/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/8068a8f5-c3ea-4bc0-a9c1-43fb3c7cd74b/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8068a8f5-c3ea-4bc0-a9c1-43fb3c7cd74b/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8068a8f5-c3ea-4bc0-a9c1-43fb3c7cd74b/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ab72ec87-b2d3-432a-ad15-701fd792902d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ab72ec87-b2d3-432a-ad15-701fd792902d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ab72ec87-b2d3-432a-ad15-701fd792902d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/b5bc9fb5-1bab-43a2-9839-d067539e2fd7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b5bc9fb5-1bab-43a2-9839-d067539e2fd7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b5bc9fb5-1bab-43a2-9839-d067539e2fd7/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/6642768e-1391-4fa3-abbf-91a1e2f51b54/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/6642768e-1391-4fa3-abbf-91a1e2f51b54/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/6642768e-1391-4fa3-abbf-91a1e2f51b54/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/55f5c522-6d80-4b71-949f-c6723d88637e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/55f5c522-6d80-4b71-949f-c6723d88637e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/55f5c522-6d80-4b71-949f-c6723d88637e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/37bd4621-cea1-4e02-9319-62efc2d7df60/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/37bd4621-cea1-4e02-9319-62efc2d7df60/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/37bd4621-cea1-4e02-9319-62efc2d7df60/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/8e607872-9dc8-409b-8cd0-5f3063950952/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8e607872-9dc8-409b-8cd0-5f3063950952/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8e607872-9dc8-409b-8cd0-5f3063950952/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1382affe-e560-4ae7-a39f-2d098bb359b8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1382affe-e560-4ae7-a39f-2d098bb359b8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1382affe-e560-4ae7-a39f-2d098bb359b8/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/21fee242-5a48-497a-a316-2aca33eefc81/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/21fee242-5a48-497a-a316-2aca33eefc81/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/21fee242-5a48-497a-a316-2aca33eefc81/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d852677c-aa75-40a1-9e71-d0de37995157/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d852677c-aa75-40a1-9e71-d0de37995157/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d852677c-aa75-40a1-9e71-d0de37995157/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/9997a5c5-31d6-43ef-a99e-661354e55b51/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9997a5c5-31d6-43ef-a99e-661354e55b51/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9997a5c5-31d6-43ef-a99e-661354e55b51/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/b600c27a-c4dd-4094-89ba-e566e62dc0b2/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b600c27a-c4dd-4094-89ba-e566e62dc0b2/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b600c27a-c4dd-4094-89ba-e566e62dc0b2/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c344ed28-3c50-4524-adf5-3a895eac4ee3/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c344ed28-3c50-4524-adf5-3a895eac4ee3/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c344ed28-3c50-4524-adf5-3a895eac4ee3/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c0bf939b-b594-4554-9c25-d3e833f91f15/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c0bf939b-b594-4554-9c25-d3e833f91f15/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c0bf939b-b594-4554-9c25-d3e833f91f15/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/2daca2af-6a5c-4a39-b869-06d2d08adcf0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2daca2af-6a5c-4a39-b869-06d2d08adcf0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2daca2af-6a5c-4a39-b869-06d2d08adcf0/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/b483b343-5dda-47a0-ab2a-68945aa2e12a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b483b343-5dda-47a0-ab2a-68945aa2e12a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b483b343-5dda-47a0-ab2a-68945aa2e12a/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/246b05d7-2816-4d36-93eb-5de36f32f436/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/246b05d7-2816-4d36-93eb-5de36f32f436/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/246b05d7-2816-4d36-93eb-5de36f32f436/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ae1c065f-f6eb-4eed-b471-d4245ffb23e1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ae1c065f-f6eb-4eed-b471-d4245ffb23e1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ae1c065f-f6eb-4eed-b471-d4245ffb23e1/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/060300a6-7b36-4443-9b9f-4e33798184c0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/060300a6-7b36-4443-9b9f-4e33798184c0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/060300a6-7b36-4443-9b9f-4e33798184c0/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/9355fbdd-f152-4256-9c6b-c6374a0c46ad/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/9355fbdd-f152-4256-9c6b-c6374a0c46ad/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/9355fbdd-f152-4256-9c6b-c6374a0c46ad/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1662aa36-8593-4916-b969-4f0236418fae/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1662aa36-8593-4916-b969-4f0236418fae/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1662aa36-8593-4916-b969-4f0236418fae/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/4330321f-7a4d-4b10-83a5-029ba8ef99bf/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4330321f-7a4d-4b10-83a5-029ba8ef99bf/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4330321f-7a4d-4b10-83a5-029ba8ef99bf/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/4fa6ec19-aa47-4c71-a1c3-bd44b0f2161f/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4fa6ec19-aa47-4c71-a1c3-bd44b0f2161f/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4fa6ec19-aa47-4c71-a1c3-bd44b0f2161f/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ce738686-cdcb-45c9-80c3-fd80b50b324e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ce738686-cdcb-45c9-80c3-fd80b50b324e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ce738686-cdcb-45c9-80c3-fd80b50b324e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/b1708969-6715-4961-8ccd-ffda04957471/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b1708969-6715-4961-8ccd-ffda04957471/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b1708969-6715-4961-8ccd-ffda04957471/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/75a694a8-cd93-4628-ae5a-d7639daea673/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/75a694a8-cd93-4628-ae5a-d7639daea673/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/75a694a8-cd93-4628-ae5a-d7639daea673/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/762c416e-402e-4e81-bb18-15924f0abd95/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/762c416e-402e-4e81-bb18-15924f0abd95/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/762c416e-402e-4e81-bb18-15924f0abd95/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/794ff264-51d3-479f-aa06-8c370b4b0c63/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/794ff264-51d3-479f-aa06-8c370b4b0c63/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/794ff264-51d3-479f-aa06-8c370b4b0c63/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/4331ba7b-5e5d-4e58-8c09-0fadb299230a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4331ba7b-5e5d-4e58-8c09-0fadb299230a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4331ba7b-5e5d-4e58-8c09-0fadb299230a/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/641888fe-5b7c-46cb-8764-7e8ae6309e4d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/641888fe-5b7c-46cb-8764-7e8ae6309e4d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/641888fe-5b7c-46cb-8764-7e8ae6309e4d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/8e710e9b-fd49-48f9-89f9-6bc257d6dcab/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8e710e9b-fd49-48f9-89f9-6bc257d6dcab/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8e710e9b-fd49-48f9-89f9-6bc257d6dcab/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/6c87da3b-1327-4f59-8588-8d7184308737/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/6c87da3b-1327-4f59-8588-8d7184308737/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/6c87da3b-1327-4f59-8588-8d7184308737/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/85263bd4-70c6-4327-a6ea-eda5db382d65/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/85263bd4-70c6-4327-a6ea-eda5db382d65/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/85263bd4-70c6-4327-a6ea-eda5db382d65/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c9eb3984-5333-4cc4-afac-ebca6afddc0d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c9eb3984-5333-4cc4-afac-ebca6afddc0d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c9eb3984-5333-4cc4-afac-ebca6afddc0d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/9464f7e1-7ba2-4a38-a98a-275052e9925c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9464f7e1-7ba2-4a38-a98a-275052e9925c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9464f7e1-7ba2-4a38-a98a-275052e9925c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/7dd82625-d505-4eaf-b196-89fec5557de0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7dd82625-d505-4eaf-b196-89fec5557de0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7dd82625-d505-4eaf-b196-89fec5557de0/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/5af346e7-4b2c-4048-9924-880f5132e62e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5af346e7-4b2c-4048-9924-880f5132e62e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5af346e7-4b2c-4048-9924-880f5132e62e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/429b98b9-6771-4861-b775-319c271616c4/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/429b98b9-6771-4861-b775-319c271616c4/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/429b98b9-6771-4861-b775-319c271616c4/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/a97ec167-34a2-4257-b37a-48a96a07a609/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a97ec167-34a2-4257-b37a-48a96a07a609/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a97ec167-34a2-4257-b37a-48a96a07a609/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/57ede067-6685-4f5d-aa58-3ccbee3c3b5d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/57ede067-6685-4f5d-aa58-3ccbee3c3b5d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/57ede067-6685-4f5d-aa58-3ccbee3c3b5d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/37ac3f08-2799-485e-93ba-6289e6bde005/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/37ac3f08-2799-485e-93ba-6289e6bde005/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/37ac3f08-2799-485e-93ba-6289e6bde005/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/62b27f31-ff6d-4990-b17a-7379a802fe8a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/62b27f31-ff6d-4990-b17a-7379a802fe8a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/62b27f31-ff6d-4990-b17a-7379a802fe8a/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/6fb460cc-2e48-4687-b66a-ba8d8baac445/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/6fb460cc-2e48-4687-b66a-ba8d8baac445/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/6fb460cc-2e48-4687-b66a-ba8d8baac445/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1ca9e7f6-e8fb-4088-ad7f-7e314da97ae8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1ca9e7f6-e8fb-4088-ad7f-7e314da97ae8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1ca9e7f6-e8fb-4088-ad7f-7e314da97ae8/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d9c77091-d7a2-4b8c-98ac-2a90a24f7b19/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d9c77091-d7a2-4b8c-98ac-2a90a24f7b19/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d9c77091-d7a2-4b8c-98ac-2a90a24f7b19/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ece9d1b7-0026-4716-bdf8-527c2706b36c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ece9d1b7-0026-4716-bdf8-527c2706b36c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ece9d1b7-0026-4716-bdf8-527c2706b36c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/dc538cc4-8ce3-4426-830c-84304b2426a9/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/dc538cc4-8ce3-4426-830c-84304b2426a9/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/dc538cc4-8ce3-4426-830c-84304b2426a9/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/41af13ca-1e43-4aeb-8404-17fc3eb46780/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/41af13ca-1e43-4aeb-8404-17fc3eb46780/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/41af13ca-1e43-4aeb-8404-17fc3eb46780/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/5c6218ce-2179-459f-b03a-1e78537509ef/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5c6218ce-2179-459f-b03a-1e78537509ef/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5c6218ce-2179-459f-b03a-1e78537509ef/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/a6b1042f-81ac-4bfa-8c21-c7b6d5d66c5a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a6b1042f-81ac-4bfa-8c21-c7b6d5d66c5a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a6b1042f-81ac-4bfa-8c21-c7b6d5d66c5a/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/2296c95c-fe4e-496a-87ab-656c104cb143/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2296c95c-fe4e-496a-87ab-656c104cb143/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2296c95c-fe4e-496a-87ab-656c104cb143/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/745e7821-e0d6-481e-b5bd-c66cc539ec69/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/745e7821-e0d6-481e-b5bd-c66cc539ec69/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/745e7821-e0d6-481e-b5bd-c66cc539ec69/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/197a742a-fc37-44c8-9b28-df191d0d2874/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/197a742a-fc37-44c8-9b28-df191d0d2874/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/197a742a-fc37-44c8-9b28-df191d0d2874/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/371041b8-a29e-4333-aa1c-e407925e31dc/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/371041b8-a29e-4333-aa1c-e407925e31dc/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/371041b8-a29e-4333-aa1c-e407925e31dc/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1d007d16-4d62-4c68-b976-587dc41ca4f1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1d007d16-4d62-4c68-b976-587dc41ca4f1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1d007d16-4d62-4c68-b976-587dc41ca4f1/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/08bb9d24-5fff-47ab-b9d2-e92ea2f44e54/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/08bb9d24-5fff-47ab-b9d2-e92ea2f44e54/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/08bb9d24-5fff-47ab-b9d2-e92ea2f44e54/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1c195386-a58f-4edb-9301-d3c8d23fcb9c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1c195386-a58f-4edb-9301-d3c8d23fcb9c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1c195386-a58f-4edb-9301-d3c8d23fcb9c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/10b4654c-2a1c-474f-aff0-010039301330/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10b4654c-2a1c-474f-aff0-010039301330/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10b4654c-2a1c-474f-aff0-010039301330/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e72d668a-ed06-4978-adbd-5a6180ed7f6e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e72d668a-ed06-4978-adbd-5a6180ed7f6e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e72d668a-ed06-4978-adbd-5a6180ed7f6e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/3bfea61e-46b5-4904-9818-4f14b47237a3/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/3bfea61e-46b5-4904-9818-4f14b47237a3/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/3bfea61e-46b5-4904-9818-4f14b47237a3/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/7b87e538-6bb7-4ef8-a318-9a243499ab1d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7b87e538-6bb7-4ef8-a318-9a243499ab1d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7b87e538-6bb7-4ef8-a318-9a243499ab1d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/f502ff28-6fff-4c17-8ace-f9488927f346/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f502ff28-6fff-4c17-8ace-f9488927f346/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f502ff28-6fff-4c17-8ace-f9488927f346/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/40a59ffd-d0aa-4a14-a58a-01b8bfda78d3/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/40a59ffd-d0aa-4a14-a58a-01b8bfda78d3/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/40a59ffd-d0aa-4a14-a58a-01b8bfda78d3/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/0bffc6c4-34c6-4d17-a54b-7c9da2a768da/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/0bffc6c4-34c6-4d17-a54b-7c9da2a768da/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/0bffc6c4-34c6-4d17-a54b-7c9da2a768da/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/4a9d3ad6-6102-40dd-b011-2b398c0a63a9/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4a9d3ad6-6102-40dd-b011-2b398c0a63a9/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4a9d3ad6-6102-40dd-b011-2b398c0a63a9/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e3faea73-2128-4d0c-bcfd-c8b566daa429/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e3faea73-2128-4d0c-bcfd-c8b566daa429/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e3faea73-2128-4d0c-bcfd-c8b566daa429/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/b3756c6f-7c3a-4445-bcb2-fc1abda7ae38/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b3756c6f-7c3a-4445-bcb2-fc1abda7ae38/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/b3756c6f-7c3a-4445-bcb2-fc1abda7ae38/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c59d6286-14e4-4d58-8281-8ebc5e8bc20e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c59d6286-14e4-4d58-8281-8ebc5e8bc20e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c59d6286-14e4-4d58-8281-8ebc5e8bc20e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ce8baca6-3070-4238-bcef-542510ba689d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ce8baca6-3070-4238-bcef-542510ba689d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ce8baca6-3070-4238-bcef-542510ba689d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/f932adb4-0fd0-4fcb-9030-a55d8c4eae45/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f932adb4-0fd0-4fcb-9030-a55d8c4eae45/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f932adb4-0fd0-4fcb-9030-a55d8c4eae45/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/4530c4bd-2246-4fdc-946b-b5070834f105/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4530c4bd-2246-4fdc-946b-b5070834f105/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4530c4bd-2246-4fdc-946b-b5070834f105/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/99d15979-9c73-4244-8039-a79a1f68f703/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/99d15979-9c73-4244-8039-a79a1f68f703/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/99d15979-9c73-4244-8039-a79a1f68f703/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/7d157248-8cd2-43f1-91e7-6cfbe473b3ae/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7d157248-8cd2-43f1-91e7-6cfbe473b3ae/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/7d157248-8cd2-43f1-91e7-6cfbe473b3ae/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/fc90304a-e616-49ab-8aa9-03e61d93c25c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/fc90304a-e616-49ab-8aa9-03e61d93c25c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/fc90304a-e616-49ab-8aa9-03e61d93c25c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/34c2df55-c5f2-4499-b278-6d8ff25c0ab7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/34c2df55-c5f2-4499-b278-6d8ff25c0ab7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/34c2df55-c5f2-4499-b278-6d8ff25c0ab7/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ccdb3f81-bdef-450a-8b83-55ba5221a604/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ccdb3f81-bdef-450a-8b83-55ba5221a604/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ccdb3f81-bdef-450a-8b83-55ba5221a604/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/939035f9-2052-4cc5-9c78-b423a5f2b612/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/939035f9-2052-4cc5-9c78-b423a5f2b612/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/939035f9-2052-4cc5-9c78-b423a5f2b612/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/60b89629-28ee-4ce0-9446-1826b7ac6677/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/60b89629-28ee-4ce0-9446-1826b7ac6677/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/60b89629-28ee-4ce0-9446-1826b7ac6677/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/018ac9aa-da37-4841-b53e-f4aacbbdd447/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/018ac9aa-da37-4841-b53e-f4aacbbdd447/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/018ac9aa-da37-4841-b53e-f4aacbbdd447/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/087986b1-941f-4f08-aff8-c41d6aba9c16/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/087986b1-941f-4f08-aff8-c41d6aba9c16/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/087986b1-941f-4f08-aff8-c41d6aba9c16/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d2a36a49-fad4-46e9-941b-c23f9be57821/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d2a36a49-fad4-46e9-941b-c23f9be57821/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d2a36a49-fad4-46e9-941b-c23f9be57821/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e66efb0a-234d-4639-bf9d-f675eea5d83f/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e66efb0a-234d-4639-bf9d-f675eea5d83f/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e66efb0a-234d-4639-bf9d-f675eea5d83f/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-8082-ad17-e5888f1ae4c6/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-8082-ad17-e5888f1ae4c6/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-8082-ad17-e5888f1ae4c6/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/4566a4c0-5f4e-41ec-894e-055ecdad96b1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4566a4c0-5f4e-41ec-894e-055ecdad96b1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/4566a4c0-5f4e-41ec-894e-055ecdad96b1/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/df917821-07ee-494a-96a4-6c3b87eefc7a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/df917821-07ee-494a-96a4-6c3b87eefc7a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/df917821-07ee-494a-96a4-6c3b87eefc7a/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/a71a6eff-7e6b-4e4e-8c0a-c09ca801208a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a71a6eff-7e6b-4e4e-8c0a-c09ca801208a/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/a71a6eff-7e6b-4e4e-8c0a-c09ca801208a/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/658f1c21-ea22-4d4d-9fef-c30bb593f43d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/658f1c21-ea22-4d4d-9fef-c30bb593f43d/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/658f1c21-ea22-4d4d-9fef-c30bb593f43d/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/29d4216e-44cf-4ae6-8780-a90b693dc3ae/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/29d4216e-44cf-4ae6-8780-a90b693dc3ae/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/29d4216e-44cf-4ae6-8780-a90b693dc3ae/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/80f90aad-3054-4007-8017-fad530dd2a41/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/80f90aad-3054-4007-8017-fad530dd2a41/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/80f90aad-3054-4007-8017-fad530dd2a41/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c1072747-ce3d-40cf-9e5f-db37f9f2c552/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c1072747-ce3d-40cf-9e5f-db37f9f2c552/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c1072747-ce3d-40cf-9e5f-db37f9f2c552/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/f2442df5-2d5d-4103-9193-785a348c499e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f2442df5-2d5d-4103-9193-785a348c499e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f2442df5-2d5d-4103-9193-785a348c499e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/14cabcf1-f0e0-452e-a428-373c6562f483/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/14cabcf1-f0e0-452e-a428-373c6562f483/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/14cabcf1-f0e0-452e-a428-373c6562f483/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/f2767045-6b28-401f-8309-24752acdab4c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f2767045-6b28-401f-8309-24752acdab4c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f2767045-6b28-401f-8309-24752acdab4c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1118ed13-2c2f-4f61-86fd-e3659bca6ecc/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1118ed13-2c2f-4f61-86fd-e3659bca6ecc/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1118ed13-2c2f-4f61-86fd-e3659bca6ecc/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d5c0d091-26c3-4ae4-b459-85943e789bdf/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d5c0d091-26c3-4ae4-b459-85943e789bdf/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d5c0d091-26c3-4ae4-b459-85943e789bdf/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/26523b15-3486-42a4-a706-682d1de6b092/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/26523b15-3486-42a4-a706-682d1de6b092/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/26523b15-3486-42a4-a706-682d1de6b092/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/56c1e18f-e93c-4501-ba1e-9fa7fd904032/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/56c1e18f-e93c-4501-ba1e-9fa7fd904032/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/56c1e18f-e93c-4501-ba1e-9fa7fd904032/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/d5fa4c05-a04b-4394-a680-0fa39501978d/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/d5fa4c05-a04b-4394-a680-0fa39501978d/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/d5fa4c05-a04b-4394-a680-0fa39501978d/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/9f3077b1-4a76-460f-9db8-db68265bf098/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9f3077b1-4a76-460f-9db8-db68265bf098/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9f3077b1-4a76-460f-9db8-db68265bf098/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/0876db06-b301-40bc-b1c0-09b4d0507138/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/0876db06-b301-40bc-b1c0-09b4d0507138/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/0876db06-b301-40bc-b1c0-09b4d0507138/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/5e8d81d1-bb2b-4a29-be1e-a661cb5007eb/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5e8d81d1-bb2b-4a29-be1e-a661cb5007eb/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/5e8d81d1-bb2b-4a29-be1e-a661cb5007eb/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1608b7c9-551e-498d-a987-56260a1cefd8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1608b7c9-551e-498d-a987-56260a1cefd8/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1608b7c9-551e-498d-a987-56260a1cefd8/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/1f4c2646-abb7-4715-b99e-10c50884d0f7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1f4c2646-abb7-4715-b99e-10c50884d0f7/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/1f4c2646-abb7-4715-b99e-10c50884d0f7/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e3b5e14a-95f0-4f7f-bbcf-522362cab157/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e3b5e14a-95f0-4f7f-bbcf-522362cab157/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e3b5e14a-95f0-4f7f-bbcf-522362cab157/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e1d08689-8534-47ce-b423-2a89b32823db/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e1d08689-8534-47ce-b423-2a89b32823db/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e1d08689-8534-47ce-b423-2a89b32823db/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-80e5-8e50-fa307913de73/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-80e5-8e50-fa307913de73/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-80e5-8e50-fa307913de73/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d922abac-11a8-445c-8113-efc31349c546/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d922abac-11a8-445c-8113-efc31349c546/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d922abac-11a8-445c-8113-efc31349c546/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/34eb7f32-6595-477f-a81f-b97856e60aeb/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/34eb7f32-6595-477f-a81f-b97856e60aeb/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/34eb7f32-6595-477f-a81f-b97856e60aeb/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/f0af7e5d-e94d-497d-9c5d-09714775c5e5/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f0af7e5d-e94d-497d-9c5d-09714775c5e5/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f0af7e5d-e94d-497d-9c5d-09714775c5e5/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/f775d94f-ee2d-4bee-b8b4-3641b530fae9/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f775d94f-ee2d-4bee-b8b4-3641b530fae9/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/f775d94f-ee2d-4bee-b8b4-3641b530fae9/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/e6cb757d-f43b-47e5-89f5-e413dc2f743c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e6cb757d-f43b-47e5-89f5-e413dc2f743c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/e6cb757d-f43b-47e5-89f5-e413dc2f743c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/200feea1-7d06-4284-a84b-e1920eea89d0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/200feea1-7d06-4284-a84b-e1920eea89d0/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/200feea1-7d06-4284-a84b-e1920eea89d0/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/2210948d-c889-4f79-bd34-abc9fe94e355/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2210948d-c889-4f79-bd34-abc9fe94e355/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2210948d-c889-4f79-bd34-abc9fe94e355/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/45457dbc-2533-47a6-b10b-7fc351fe36af/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/45457dbc-2533-47a6-b10b-7fc351fe36af/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/45457dbc-2533-47a6-b10b-7fc351fe36af/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/21287f93-a965-47e2-89fc-2649f64028f0/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/21287f93-a965-47e2-89fc-2649f64028f0/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/21287f93-a965-47e2-89fc-2649f64028f0/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/8f256a77-722a-4341-889f-580b39f94de2/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8f256a77-722a-4341-889f-580b39f94de2/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/8f256a77-722a-4341-889f-580b39f94de2/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/2fce5f7b-b98b-4f92-b8e5-282ff9f0147c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2fce5f7b-b98b-4f92-b8e5-282ff9f0147c/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/2fce5f7b-b98b-4f92-b8e5-282ff9f0147c/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/315d4c5b-0716-4b8f-b4a3-88e6140f3981/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/315d4c5b-0716-4b8f-b4a3-88e6140f3981/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/315d4c5b-0716-4b8f-b4a3-88e6140f3981/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/3bdb66bc-f062-4a73-9934-7f6499ae8f78/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/3bdb66bc-f062-4a73-9934-7f6499ae8f78/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/3bdb66bc-f062-4a73-9934-7f6499ae8f78/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/ce375e75-dc6a-45ec-af53-480d4fa7963e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ce375e75-dc6a-45ec-af53-480d4fa7963e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/ce375e75-dc6a-45ec-af53-480d4fa7963e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/63e275a1-a3e8-4688-8805-ac4e7f896170/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/63e275a1-a3e8-4688-8805-ac4e7f896170/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/63e275a1-a3e8-4688-8805-ac4e7f896170/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c4f49b7f-510d-406d-a5fd-ac2d1d3e46f2/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c4f49b7f-510d-406d-a5fd-ac2d1d3e46f2/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c4f49b7f-510d-406d-a5fd-ac2d1d3e46f2/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/9dd4f9db-f7d5-4845-b5c4-6ef1deb3be2e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9dd4f9db-f7d5-4845-b5c4-6ef1deb3be2e/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/9dd4f9db-f7d5-4845-b5c4-6ef1deb3be2e/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/146e0628-bbc6-4d02-b0b5-28564d230da1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/146e0628-bbc6-4d02-b0b5-28564d230da1/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/146e0628-bbc6-4d02-b0b5-28564d230da1/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/d2c0fc2a-c737-4dc3-a6f7-e70cae425527/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d2c0fc2a-c737-4dc3-a6f7-e70cae425527/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/d2c0fc2a-c737-4dc3-a6f7-e70cae425527/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-804c-b060-d723678cafd5/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-804c-b060-d723678cafd5/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/10d1e09c-3048-804c-b060-d723678cafd5/children "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.notion.com/v1/databases/386955c1-cba1-4a6d-bc41-4dad6a105ae2/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/386955c1-cba1-4a6d-bc41-4dad6a105ae2/query "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.notion.com/v1/databases/386955c1-cba1-4a6d-bc41-4dad6a105ae2/query "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://api.notion.com/v1/blocks/c49bff40-ecc4-4cb7-a5e2-197bf6095d1b/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c49bff40-ecc4-4cb7-a5e2-197bf6095d1b/children "HTTP/1.1 200 OK"
# HTTP Request: GET https://api.notion.com/v1/blocks/c49bff40-ecc4-4cb7-a5e2-197bf6095d1b/children "HTTP/1.1 200 OK"

# %%
from llama_index.core import Document

documents = [Document(text=record['content'], metadata=record['properties']) for record in processed_data]

# %%
documents[0].__dict__
# Out:
# {'id_': '05d66872-f820-4560-9ce3-a2a8b463c08a',
#  'embedding': None,
#  'metadata': {'Employer': 'McMaster University - Partnered with Stellantis',
#   'Description': 'Maintained and improved the  Boundary Diagram Tool  (BDT) for change impact analysis in large-scale Simulink models, specifically for automotive systems at Stellantis   ',
#   'Project Size': 'Medium',
#   'When': '2020-06-01',
#   'Position': 'Research Assistant',
#   'Tags': ['MATLAB', 'Simulink'],
#   'Name': 'MATLAB/Simulink - Boundary Diagram Tool',
#   'header': 'Project Overview:'},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'text': 'The  Boundary Diagram Tool (BDT)  is an advanced tool designed for  change impact analysis  in large-scale Simulink models, particularly those used in embedded systems like automotive control units. The tool enables engineers to trace how changes in specific parts of a system propagate through other models and network interfaces, aiding in software maintenance, debugging, and ensuring compliance with safety standards like  ISO 26262 . It was developed as part of a collaboration with  Stellantis  (formerly FCA), where it played a key role in managing changes within complex automotive systems, such as  hybrid electric vehicle control systems .\nAs part of the development team, my work on the BDT Tool involved both using the tool for various critical tasks and improving its functionality to make it more efficient and reliable.',
#  'mimetype': 'text/plain',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %%
from llama_index.core.node_parser import SentenceSplitter

sentence_splitter = SentenceSplitter(
    chunk_size=512, # in tokens
    chunk_overlap=16, # in tokens
    paragraph_separator="\n\n\n"
)

nodes = sentence_splitter.get_nodes_from_documents(documents, show_progress=True)
# Out:
# Parsing nodes: 100%|██████████| 96/96 [00:00<00:00, 2128.80it/s]

# %%
len(nodes)
# Out:
# 99

# %%
#from llama_index.embeddings.cohere import CohereEmbedding
from llama_index.embeddings.openai import OpenAIEmbedding

CO_API_KEY = os.environ['CO_API_KEY'] or getpass("Enter your Cohere API key: ")

embed_model = OpenAIEmbedding(model_name="text-embedding-3-small")

# %%
import qdrant_client
from llama_index.vector_stores.qdrant import QdrantVectorStore

QDRANT_URL = os.environ['QDRANT_URL']
QDRANT_API_KEY = os.environ['QDRANT_API_KEY']

# initialize qdrant client
client = qdrant_client.QdrantClient(
    url=QDRANT_URL, 
    api_key=QDRANT_API_KEY,
)

vector_store = QdrantVectorStore(
    client=client, 
    collection_name="Notion_vector_store",
    embed_model=embed_model,
)
# Out:
# INFO:httpx:HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/exists "HTTP/1.1 200 OK"
# HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/exists "HTTP/1.1 200 OK"
# HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/exists "HTTP/1.1 200 OK"

# %%
from llama_index.core import StorageContext

# assign qdrant vector store to storage context
storage_context = StorageContext.from_defaults(
    vector_store=vector_store,
    )

# %%
from llama_index.core import  VectorStoreIndex

# create the index
index = VectorStoreIndex(
    nodes,
    show_progress=True,
    store_nodes_override=True,
    #transformation=[sentence_splitter],
    embed_model=embed_model,
    storage_context=storage_context,
)
# Out:
# Generating embeddings:   0%|          | 0/99 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Generating embeddings: 100%|██████████| 99/99 [00:01<00:00, 52.47it/s]
# INFO:httpx:HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/index?wait=true "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/index?wait=true "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/index?wait=true "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/exists "HTTP/1.1 200 OK"
# HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/exists "HTTP/1.1 200 OK"
# HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/exists "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store "HTTP/1.1 200 OK"
# HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store "HTTP/1.1 200 OK"
# HTTP Request: GET https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points?wait=true "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points?wait=true "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points?wait=true "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points?wait=true "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points?wait=true "HTTP/1.1 200 OK"
# HTTP Request: PUT https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points?wait=true "HTTP/1.1 200 OK"

# %%
from llama_index.llms.cohere import Cohere
from llama_index.core import get_response_synthesizer
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor

llm = Cohere(model="command-r-plus")

# configure a retriever
retriever = VectorIndexRetriever(
    index=index,
    similarity_top_k=15,
)

# configure a post processor
similarity_processor = SimilarityPostprocessor(similarity_cutoff=0.3)

# configure a response sythesizer
response_synthsizer = get_response_synthesizer(llm=llm)

# create a query engine
query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthsizer,
    node_postprocessors=[similarity_processor],
)

# %%
response = query_engine.query("Outline work done that involved the use of embedded systems")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points/search "HTTP/1.1 200 OK"
# HTTP Request: POST https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points/search "HTTP/1.1 200 OK"
# HTTP Request: POST https://0a690c49-5e88-4998-82fe-3be37b2cc61d.us-east4-0.gcp.cloud.qdrant.io:6333/collections/Notion_vector_store/points/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 200 OK"

# %%
for node in response.source_nodes:
    print(node.score)
# Out:
# 0.5184556
# 0.5076841
# 0.5056155
# 0.504579
# 0.5045206
# 0.485343
# 0.47040236
# 0.46849632
# 0.4519909
# 0.4500804
# 0.44908825
# 0.44807273
# 0.44527188
# 0.4442506
# 0.4425006

# %%
print(response.response)
# Out:
# I have been involved in several projects that utilized embedded systems:
#
# - Cobra 55 Bootloader RAM Project: Developed a custom bootloader for the Cobra 55 microcontroller, allowing it to establish an Ethernet connection, receive a program, store it in RAM, and execute it. This project involved in-depth knowledge of embedded systems memory management and bootloader development.
#
# - Stroke Rehabilitation Using EMG-Driven Tetris Game: Designed and built a wearable device for stroke patients to rehabilitate fine-motor skills. This involved using surface EMG technology to collect data, process it using embedded software, and transmit it to a Tetris game for rehabilitation.
#
# - Quadcopter Development and Testing: Assembled, tested, and programmed a quadcopter, including working with various embedded systems such as the Pixhawk flight controller, sensors, and the Raspberry Pi for enhanced processing and computer vision capabilities.
#
# - Cubic Gridsmart (GS3) Deployment: Deployed a Radar-Fusion Python script on Cubic's GridSmart system, which involved setting up a Python and ROS2 environment, interfacing with external hardware, and ensuring stable network configuration between a Jetson Nano and an Intel Processor.
